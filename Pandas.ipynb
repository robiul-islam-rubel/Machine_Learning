# %% [markdown]
# <a href="https://colab.research.google.com/github/robiul-islam-rubel/Machine_Learning/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import pandas
import pandas as pd

# %%
# create dataframe
pd.DataFrame({'Yes':[50,21],'No':[45,89]})
# Out:
#    Yes  No
# 0   50  45
# 1   21  89

# %%
# create another dataframe
df = pd.DataFrame({'Rubel':[4.00,4.08,3.99],'Alamin':[4.65,3.25,3.95]},index=['SSC','HSC','BSC'])

# %%
# show first 5 rows
df.head()
# Out:
#      Rubel  Alamin
# SSC   4.00    4.65
# HSC   4.08    3.25
# BSC   3.99    3.95

# %%
# show number of rows and columns
df.shape
# Out:
# (3, 2)

# %%
# show single column value
df.Rubel
# Out:
# SSC    4.00
# HSC    4.08
# BSC    3.99
# Name: Rubel, dtype: float64

# %%
# show single column value
df['Rubel']
# Out:
# SSC    4.00
# HSC    4.08
# BSC    3.99
# Name: Rubel, dtype: float64

# %%
# show only one value
df['Rubel'][0]
# Out:
# 4.0

# %%
# show 0th row
df.iloc[0]
# Out:
# Rubel     4.00
# Alamin    4.65
# Name: SSC, dtype: float64

# %%
# show 1th row
df.iloc[1]
# Out:
# Rubel     4.08
# Alamin    3.25
# Name: HSC, dtype: float64

# %%
# rename the index
df.rename(index={0:'firstentry',1:'secondentry',2:'Thirdentry'})
# Out:
#      Rubel  Alamin
# SSC   4.00    4.65
# HSC   4.08    3.25
# BSC   3.99    3.95

# %%
# overview of the data
df.describe()
# Out:
#           Rubel  Alamin
# count  3.000000    3.00
# mean   4.023333    3.95
# std    0.049329    0.70
# min    3.990000    3.25
# 25%    3.995000    3.60
# 50%    4.000000    3.95
# 75%    4.040000    4.30
# max    4.080000    4.65

# %%
# count value
df.value_counts()
# Out:
# Rubel  Alamin
# 3.99   3.95      1
# 4.00   4.65      1
# 4.08   3.25      1
# dtype: int64
